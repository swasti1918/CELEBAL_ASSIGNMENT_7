# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/celebal/bin/python

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.11

# %%
import langchain_community
print("langchain_community imported successfully")
# Out:
# langchain_community imported successfully
# /var/folders/_t/6m9gfzt9545d2mhcv_n50x7m0000gn/T/ipykernel_57363/2064975958.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   import langchain_community

# %%
import sys
# !{sys.executable} -m pip install -U langchain-text-splitters
# Out:
# Requirement already satisfied: langchain-text-splitters in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-text-splitters) (1.4.8)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.9.7)
# Requirement already satisfied: packaging>=23.2.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.13.0)
# Requirement already satisfied: distro>=1.7.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.7.0)

# %%
import os

from tkinter import Tk
from tkinter.filedialog import askopenfilename

from langchain_community.document_loaders import PyPDFLoader

from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_google_genai import (
    GoogleGenerativeAIEmbeddings,
    ChatGoogleGenerativeAI,
)

from langchain_community.vectorstores import FAISS

print("Everything imported successfully!")
# Out:
# Everything imported successfully!

# %%
import os

os.environ["GOOGLE_API_KEY"] = "YOUR API KEY"

# %%
import os

print(os.environ["GOOGLE_API_KEY"][:10])
# Out:
# AQ.Ab8RN6I

# %%
from langchain_community.document_loaders import PyPDFLoader

pdf_path = "/Users/itech/Downloads/Swasti_Jain_PIET23CS162.pdf"   

loader = PyPDFLoader(pdf_path)
documents = loader.load()

print("Total Pages:", len(documents))
# Out:
# /var/folders/_t/6m9gfzt9545d2mhcv_n50x7m0000gn/T/ipykernel_58291/1763587908.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader
# Total Pages: 2

# %%
print(documents[0].page_content[:1000])
# Out:
# Swasti Jain
# Phone: +91-7062062066 Jaipur, Rajasthan, India
# GitHub: Swasti1918 Email: jnswasti07@gmail.com LinkedIn: Swasti Jain
# Objective
# Aspiring Software Engineer with strong fundamentals in Data Structures, Object-Oriented Programming, and
# Python, along with hands-on experience in Machine Learning. Interested in building scalable applications and
# gaining exposure to AI, cloud platforms, APIs, and DevOps practices.
# Education
# Bachelor of T echnology (B.T ech) in Computer Science and Engineering2023 – 2027
# Poornima Institute of Engineering and Technology, Jaipur
# Technical Skills
# Programming Languages:Java, Python, SQL, JavaScript
# Machine Learning:XGBoost, Scikit-learn, Model Evaluation, Feature Engineering
# W eb and Deployment:Gradio, Hugging Face Spaces, Streamlit, REST APIs
# Cloud & DevOps:Basic Docker, CI/CD Concepts, Cloud Fundamentals (A WS/Azure)
# Core Concepts:Data Structures, Algorithms, Object-Oriented Programming (OOP)
# T ools and T echnologies:Git, GitHub
# Projects
# Cancer Predict

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

docs = text_splitter.split_documents(documents)

print("Total Chunks:", len(docs))
# Out:
# Total Chunks: 7

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(
    model="models/embedding-001",
    google_api_key="YOUR API KEY"
)
print("Embeddings object created successfully!")
# Out:
# Embeddings object created successfully!

# %%
import sys
# !{sys.executable} -m pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.6.0-py3-none-any.whl.metadata (18 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.13.0-py3-none-any.whl.metadata (32 kB)
# Collecting huggingface-hub>=0.23.0 (from sentence-transformers)
#   Downloading huggingface_hub-1.22.0-py3-none-any.whl.metadata (14 kB)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.12.1-cp311-cp311-macosx_14_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from sentence-transformers) (2.4.6)
# Requirement already satisfied: scikit-learn>=0.22.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from sentence-transformers) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from sentence-transformers) (1.17.1)
# Requirement already satisfied: typing_extensions>=4.5.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from sentence-transformers) (4.68.3)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Collecting regex>=2025.10.22 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading regex-2026.6.28-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl.metadata (7.3 kB)
# Collecting typer (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading typer-0.26.8-py3-none-any.whl.metadata (15 kB)
# Collecting safetensors>=0.8.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting click<9.0.0,>=8.4.2 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting filelock>=3.10.0 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading filelock-3.29.5-py3-none-any.whl.metadata (2.0 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading fsspec-2026.6.0-py3-none-any.whl.metadata (10 kB)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub>=0.23.0->sentence-transformers)
#   Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.13.0)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: joblib>=1.4.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Collecting setuptools<82 (from torch>=1.11.0->sentence-transformers)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Collecting shellingham>=1.3.0 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=13.8.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Collecting annotated-doc>=0.0.2 (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/celebal/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Downloading sentence_transformers-5.6.0-py3-none-any.whl (596 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 596.4/596.4 kB 3.1 MB/s  0:00:00
# Downloading transformers-5.13.0-py3-none-any.whl (11.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 5.0 MB/s  0:00:025.0 MB/s eta 0:00:01:01
# Downloading huggingface_hub-1.22.0-py3-none-any.whl (765 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 765.1/765.1 kB 5.6 MB/s  0:00:00
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 5.6 MB/s  0:00:005.9 MB/s eta 0:00:01:01
# Downloading tokenizers-0.22.2-cp39-abi3-macosx_11_0_arm64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 5.8 MB/s  0:00:005.9 MB/s eta 0:00:01
# Downloading filelock-3.29.5-py3-none-any.whl (45 kB)
# Downloading fsspec-2026.6.0-py3-none-any.whl (203 kB)
# Downloading regex-2026.6.28-cp311-cp311-macosx_11_0_arm64.whl (289 kB)
# Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl (484 kB)
# Downloading torch-2.12.1-cp311-cp311-macosx_14_0_arm64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 5.5 MB/s  0:00:15 eta 0:00:010:00:01
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 5.5 MB/s  0:00:00
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.6 MB/s  0:00:006.1 MB/s eta 0:00:01
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 5.8 MB/s  0:00:015.8 MB/s eta 0:00:01:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 5.7 MB/s  0:00:00
# Downloading typer-0.26.8-py3-none-any.whl (122 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Installing collected packages: mpmath, sympy, shellingham, setuptools, safetensors, regex, networkx, hf-xet, fsspec, filelock, click, annotated-doc, torch, typer, huggingface-hub, tokenizers, transformers, sentence-transformers
#   Attempting uninstall: setuptools237m╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/18 [sympy]
#     Found existing installation: setuptools 82.0.1━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/18 [sympy]
#     Uninstalling setuptools-82.0.1:━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/18 [sympy]
#       Successfully uninstalled setuptools-82.0.1m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  3/18 [setuptools]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [sentence-transformers]17/18 [sentence-transformers]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.21.0 requires protobuf<8.0.0,>=6.31.1, but you have protobuf 5.29.6 which is incompatible.
# Successfully installed annotated-doc-0.0.4 click-8.4.2 filelock-3.29.5 fsspec-2026.6.0 hf-xet-1.5.1 huggingface-hub-1.22.0 mpmath-1.3.0 networkx-3.6.1 regex-2026.6.28 safetensors-0.8.0 sentence-transformers-5.6.0 setuptools-81.0.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.12.1 transformers-5.13.0 typer-0.26.8

# %%
import os

from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings

from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# /var/folders/_t/6m9gfzt9545d2mhcv_n50x7m0000gn/T/ipykernel_58649/3310764245.py:3: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import PyPDFLoader

# %%
import os

os.environ["GOOGLE_API_KEY"] = "YOUR API KEY"

# %%
loader = PyPDFLoader("/Users/itech/Downloads/Swasti_Jain_PIET23CS162.pdf")

documents = loader.load()

print("Pages:", len(documents))
# Out:
# Pages: 2

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200
)

docs = text_splitter.split_documents(documents)

print("Chunks:", len(docs))
# Out:
# Chunks: 7

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

print("Embeddings Created")
# Out:
# /var/folders/_t/6m9gfzt9545d2mhcv_n50x7m0000gn/T/ipykernel_58649/3892875339.py:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Embeddings Created

# %%
vector_store = FAISS.from_documents(
    docs,
    embeddings
)

print("Vector Store Created Successfully!")
# Out:
# Vector Store Created Successfully!

# %%
question = input("Enter your question: ")
# Out:
# Enter your question:  what are my technical skills?

# %%
retriever = vector_store.as_retriever(search_kwargs={"k": 3})

retrieved_docs = retriever.invoke(question)

print(f"Retrieved {len(retrieved_docs)} documents.")
# Out:
# Retrieved 3 documents.

# %%
for i, doc in enumerate(retrieved_docs, 1):
    print(f"\n----- Document {i} -----")
    print(doc.page_content)
# Out:
# ----- Document 1 -----
# presentation, and technical implementation skills.
# •Actively practicingData Structures and Algorithms (DSA)on platforms like LeetCode, strengthening
# problem-solving and algorithmic thinking abilities.
#
# ----- Document 2 -----
# Swasti Jain
# Phone: +91-7062062066 Jaipur, Rajasthan, India
# GitHub: Swasti1918 Email: jnswasti07@gmail.com LinkedIn: Swasti Jain
# Objective
# Aspiring Software Engineer with strong fundamentals in Data Structures, Object-Oriented Programming, and
# Python, along with hands-on experience in Machine Learning. Interested in building scalable applications and
# gaining exposure to AI, cloud platforms, APIs, and DevOps practices.
# Education
# Bachelor of T echnology (B.T ech) in Computer Science and Engineering2023 – 2027
# Poornima Institute of Engineering and Technology, Jaipur
# Technical Skills
# Programming Languages:Java, Python, SQL, JavaScript
# Machine Learning:XGBoost, Scikit-learn, Model Evaluation, Feature Engineering
# W eb and Deployment:Gradio, Hugging Face Spaces, Streamlit, REST APIs
# Cloud & DevOps:Basic Docker, CI/CD Concepts, Cloud Fundamentals (A WS/Azure)
# Core Concepts:Data Structures, Algorithms, Object-Oriented Programming (OOP)
# T ools and T echnologies:Git, GitHub
# Projects
#
# ----- Document 3 -----
# •Built GUI applications using Tkinter for data entry and visualization.
# •Used Git for version control and team collaboration in a team-based development environment.
# AI Tools and Technologies
# Large Language Models (LLMs):ChatGPT, Claude, Gemini
# AI Platforms & APIs:OpenAI API, Hugging Face
# AI Development T ools:Cursor, GitHub Copilot
# AI Agents & F rameworks:Antigravity
# AI Concepts:LLMs, Prompt Engineering, Retrieval-Augmented Generation (RAG), Vector Databases
# Prompt Engineering:Few-shot Prompting, Chain-of-Thought, Context Engineering
# Achievements
# •Participated inSmart India Hackathon (SIH) 2024, a national-level innovation competition, collaborating
# in a team to develop problem-solving solutions under real-world constraints.
# •Represented a technical project at aNational Level Project Exhibition 2024, demonstrating innovation,
# presentation, and technical implementation skills.
# •Actively practicingData Structures and Algorithms (DSA)on platforms like LeetCode, strengthening

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    google_api_key="YOUR API KEY"   
)

# %%
context = "\n\n".join([doc.page_content for doc in retrieved_docs])

prompt = f"""
You are a helpful assistant.

Answer ONLY using the information provided in the context.

If the answer is not available in the context, say:
"I could not find that information in the document."

Context:
{context}

Question:
{question}
"""

response = llm.invoke(prompt)

print("\nAnswer:\n")
print(response.content)
# Out:
# Answer:
#
# Technical Skills:
# *   **Programming Languages:** Java, Python, SQL, JavaScript
# *   **Machine Learning:** XGBoost, Scikit-learn, Model Evaluation, Feature Engineering
# *   **Web and Deployment:** Gradio, Hugging Face Spaces, Streamlit, REST APIs
# *   **Cloud & DevOps:** Basic Docker, CI/CD Concepts, Cloud Fundamentals (AWS/Azure)
# *   **Core Concepts:** Data Structures, Algorithms, Object-Oriented Programming (OOP)
# *   **Tools and Technologies:** Git, GitHub
